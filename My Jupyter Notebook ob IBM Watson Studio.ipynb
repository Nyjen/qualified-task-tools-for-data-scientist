# %% [markdown]
# <h1>My Jupyter Notebook ob IBM Watson Studio<h1>

# %% [markdown]
# **Nacho Jiménez**
#
# Data Scientist Student

# %% [markdown]
# *I'm interested in Data Science because I believe that only a well-informed organization can make the right decisions, and it pays very well.*

# %% [markdown]
# <H3>MATHEMATICAL OPERATIONS WITH CODE<H3>

# %%
(1+1+3)*2
# Out:
# 10

# %% [markdown]
# BULLETED LIST:
# * Item 1
# * Item 2
# * Item 3
#
#
#
# NUMERED LIST:
# 1. Item house
# 2. Item university
# 3. Item hospital
#
#
#
# HYPERLINK:
#
# [LINK TO GOOGLE](https://www.google.com)
